# %% [markdown]
# **IMPORTING CSV FILES**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/college_student_placement_dataset.csv')

# %%
df.describe()
# Out:
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# ...

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df.head(18)
# Out:
#    College_ID   IQ  Prev_Sem_Result   CGPA  Academic_Performance  \
# 0     CLG0030  107             6.61   6.28                     8
# 1     CLG0061   97             5.52   5.37                     8
# 2     CLG0036  109             5.36   5.83                     9
# 3     CLG0055  122             5.47   5.75                     6
# 4     CLG0004   96             7.91   7.69                     7
# 5     CLG0015   96             5.26   5.32                     7
# 6     CLG0071  123             6.68   6.58                     5
# 7     CLG0096  111             8.77   8.76                     7
# 8     CLG0097   92             6.47   6.33                     9
# 9     CLG0057  108             8.82   8.60                     4
# 10    CLG0063   93             8.73   8.90                     2
# 11    CLG0077   93             6.23   6.51                     8
# 12    CLG0064  103             8.64   9.01                     7
# ...

# %%
df.tail()
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 9995                    No                       1                     8
# 9996                    No                       0                     7
# 9997                   Yes                       3                     9
# 9998                    No                       7                     5
# 9999                    No                       3                     5
#
#       Projects_Completed Placement
# 9995                   0       Yes
# 9996                   2        No
# ...

# %%
df.tail(18)
# Out:
#      College_ID   IQ  Prev_Sem_Result   CGPA  Academic_Performance  \
# 9982    CLG0043  107             5.30   5.26                     1
# 9983    CLG0014  103             7.36   7.35                     5
# 9984    CLG0089   82             7.58   7.56                     1
# 9985    CLG0052   94             9.27   9.37                     6
# 9986    CLG0027   94             8.66   8.19                     8
# 9987    CLG0093   73             5.40   5.89                     7
# 9988    CLG0052   85             6.05   6.27                     1
# 9989    CLG0001   88             6.56   6.49                     8
# 9990    CLG0046  121             5.58   5.27                     9
# 9991    CLG0005  102             7.28   6.86                    10
# 9992    CLG0062  109             9.92  10.09                     2
# 9993    CLG0056   77             7.57   7.39                     1
# 9994    CLG0064  117             8.71   8.44                     6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df.columns
# Out:
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %% [markdown]
# **IMPORTING TEXT FILES**

# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/business_1.txt',delimiter='\t')

# %%
df1.describe()
# Out:
#                            Lufthansa flies back to profit
# count                                                   2
# unique                                                  2
# top     German airline Lufthansa has returned to profi...
# freq                                                    1

# %%
df1.head()
# Out:
#                       Lufthansa flies back to profit
# 0  German airline Lufthansa has returned to profi...
# 1  In a preliminary report, the airline announced...

# %%
df1.tail()
# Out:
#                       Lufthansa flies back to profit
# 0  German airline Lufthansa has returned to profi...
# 1  In a preliminary report, the airline announced...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Lufthansa flies back to profit  2 non-null      object
# dtypes: object(1)
# memory usage: 148.0+ bytes

# %%
df1.columns
# Out:
# Index(['Lufthansa flies back to profit'], dtype='object')

# %% [markdown]
# **IMPORTING EXCEL FILES**

# %%
import pandas as pd

# %%
df2=pd.read_excel('/content/Cola.xlsx')

# %%
df2.describe()
# Out:
#         Data provided by SimFin      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# count                         3              97         82         82
# unique                        3              90         77         77
# top     Profit & Loss statement  in million USD     FY '09     FY '10
# freq                          1               3          3          3
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# count          82         82         82         82          90          92
# unique         77         77         77         78          79          78
# top        FY '11     FY '12     FY '13     FY '14           0           0
# freq            3          3          3          3           6           8
#
#        Unnamed: 10 Unnamed: 11
# count           93          93
# unique          87          86
# top         FY '17      FY '18
# freq             3           3

# %%
df2.head()
# Out:
#    Data provided by SimFin              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      NaN                     NaN        NaN        NaN
# 1  Profit & Loss statement                     NaN        NaN        NaN
# 2                      NaN          in million USD     FY '09     FY '10
# 3                      NaN  NET OPERATING REVENUES      30990      35119
# 4                      NaN      Cost of goods sold      11088      12693
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2     FY '11     FY '12     FY '13     FY '14     FY '15     FY '16
# 3      46542      48017      46854      45998      44294      41863
# 4      18215      19053      18421      17889      17482      16465
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2      FY '17      FY '18
# ...

# %%
df2.head(18)
# Out:
#     Data provided by SimFin  \
# 0                       NaN
# 1   Profit & Loss statement
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                      in million USD     FY '09     FY '10
# 3                              NET OPERATING REVENUES      30990      35119
# ...

# %%
df2.tail()
# Out:
#     Data provided by SimFin  \
# 98                      NaN
# 99                      NaN
# 100                     NaN
# 101                     NaN
# 102                     NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 98   Effect of exchange rate changes on cash and ca...        576       -166
# 99   Cash Provided by (Used in) Investing Activitie...        NaN        NaN
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 98        -430       -255       -611       -934       -878         -6
# 99         NaN        NaN        NaN        NaN          0          0
# 100        NaN        NaN        NaN        NaN          0          0
# ...

# %%
df2.tail(18)
# Out:
#     Data provided by SimFin  \
# 85                      NaN
# 86                      NaN
# 87                      NaN
# 88                      NaN
# 89                      NaN
# 90                      NaN
# 91                      NaN
# 92                      NaN
# 93                      NaN
# 94                      NaN
# 95                      NaN
# 96                      NaN
# 97                      NaN
# 98                      NaN
# 99                      NaN
# 100                     NaN
# 101                     NaN
# 102                     NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 85   Proceeds from disposals of businesses, equity ...        240        972
# 86          Purchases of property, plant and equipment      -1993      -2215
# 87   Proceeds from disposals of property, plant and...        104        134
# 88                          Other investing activities        -48       -106
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data provided by SimFin  3 non-null      object
#  1   Unnamed: 1               97 non-null     object
#  2   Unnamed: 2               82 non-null     object
#  3   Unnamed: 3               82 non-null     object
#  4   Unnamed: 4               82 non-null     object
#  5   Unnamed: 5               82 non-null     object
#  6   Unnamed: 6               82 non-null     object
#  7   Unnamed: 7               82 non-null     object
#  8   Unnamed: 8               90 non-null     object
#  9   Unnamed: 9               92 non-null     object
#  10  Unnamed: 10              93 non-null     object
#  11  Unnamed: 11              93 non-null     object
# dtypes: object(12)
# memory usage: 9.8+ KB

# %%
df2.columns
# Out:
# Index(['Data provided by SimFin', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')
